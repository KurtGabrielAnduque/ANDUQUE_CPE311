# %%
# What could you have done better??

'''
If I only have a knoledge about the given dataset I think I can do more transformations form the given dataset
'''

# %% [markdown]
# <font size = 7>EXTRACTION PHASE</font>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt



df = pd.read_csv("RT_IOT2022.csv")

df.head()
# Out:
#    no  id.orig_p  id.resp_p proto service  flow_duration  fwd_pkts_tot  \
# 0   0      38667       1883   tcp    mqtt      32.011598             9
# 1   1      51143       1883   tcp    mqtt      31.883584             9
# 2   2      44761       1883   tcp    mqtt      32.124053             9
# 3   3      60893       1883   tcp    mqtt      31.961063             9
# 4   4      51087       1883   tcp    mqtt      31.902362             9
#
#    bwd_pkts_tot  fwd_data_pkts_tot  bwd_data_pkts_tot  ...  active.std  \
# 0             5                  3                  3  ...         0.0
# 1             5                  3                  3  ...         0.0
# 2             5                  3                  3  ...         0.0
# 3             5                  3                  3  ...         0.0
# 4             5                  3                  3  ...         0.0
#
#        idle.min      idle.max      idle.tot      idle.avg  idle.std  \
# ...

# %% [markdown]
# <font size = 7>TRASNFORMATION PHASE</font>

# %%
#chech the datatype so the columns of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123117 entries, 0 to 123116
# Data columns (total 85 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   no                        123117 non-null  int64
#  1   id.orig_p                 123117 non-null  int64
#  2   id.resp_p                 123117 non-null  int64
#  3   proto                     123117 non-null  object
#  4   service                   123117 non-null  object
#  5   flow_duration             123117 non-null  float64
#  6   fwd_pkts_tot              123117 non-null  int64
#  7   bwd_pkts_tot              123117 non-null  int64
#  8   fwd_data_pkts_tot         123117 non-null  int64
#  9   bwd_data_pkts_tot         123117 non-null  int64
#  10  fwd_pkts_per_sec          123117 non-null  float64
#  11  bwd_pkts_per_sec          123117 non-null  float64
#  12  flow_pkts_per_sec         123117 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# no                      0
# id.orig_p               0
# id.resp_p               0
# proto                   0
# service                 0
#                        ..
# idle.std                0
# fwd_init_window_size    0
# bwd_init_window_size    0
# fwd_last_window_size    0
# Attack_type             0
# Length: 85, dtype: int64

# %% [markdown]
# <font size = 7>LOAD PHASE</font>

# %%
# finding the distribution of attack types


df['Attack_type'].value_counts(normalize =  True)
# Out:
# Attack_type
# DOS_SYN_Hping                 0.768854
# Thing_Speak                   0.065856
# ARP_poisioning                0.062948
# MQTT_Publish                  0.033675
# NMAP_UDP_SCAN                 0.021037
# NMAP_XMAS_TREE_SCAN           0.016326
# NMAP_OS_DETECTION             0.016245
# NMAP_TCP_scan                 0.008139
# DDOS_Slowloris                0.004337
# Wipro_bulb                    0.002055
# Metasploit_Brute_Force_SSH    0.000301
# NMAP_FIN_SCAN                 0.000227
# Name: proportion, dtype: float64

# %%
df['Attack_type'].value_counts()
# Out:
# Attack_type
# DOS_SYN_Hping                 94659
# Thing_Speak                    8108
# ARP_poisioning                 7750
# MQTT_Publish                   4146
# NMAP_UDP_SCAN                  2590
# NMAP_XMAS_TREE_SCAN            2010
# NMAP_OS_DETECTION              2000
# NMAP_TCP_scan                  1002
# DDOS_Slowloris                  534
# Wipro_bulb                      253
# Metasploit_Brute_Force_SSH       37
# NMAP_FIN_SCAN                    28
# Name: count, dtype: int64

# %%
df[df.service == "-"].describe()
# Out:
#                   no      id.orig_p      id.resp_p  flow_duration  \
# count  102861.000000  102861.000000  102861.000000  102861.000000
# mean    43649.726796   32325.035601    1002.998435       1.081663
# std     29042.616145   19580.066801    5702.150883     111.275547
# min         0.000000       0.000000       0.000000       0.000000
# 25%     17513.000000   14248.000000      21.000000       0.000001
# 50%     43228.000000   33327.000000      21.000000       0.000004
# 75%     68943.000000   50060.000000      21.000000       0.000004
# max     94658.000000   65535.000000   65389.000000   21728.335578
#
#         fwd_pkts_tot   bwd_pkts_tot  fwd_data_pkts_tot  bwd_data_pkts_tot  \
# count  102861.000000  102861.000000      102861.000000      102861.000000
# mean        1.251728       1.014942           1.174624           0.136048
# std        20.935417       8.121149          20.836791           8.109191
# min         0.000000       0.000000           0.000000           0.000000
# ...

# %%
df.query(

# %%
attack_type = list(df['Attack_type'].unique())

for name in attack_type:
    check = df[(df['Attack_type'] == name) & (df['service'] == "-")].shape[0]
    if check  > 0:
        print(name)
# Out:
# MQTT_Publish
# Thing_Speak
# Wipro_bulb
# ARP_poisioning
# DDOS_Slowloris
# DOS_SYN_Hping
# NMAP_FIN_SCAN
# NMAP_OS_DETECTION
# NMAP_TCP_scan
# NMAP_UDP_SCAN
# NMAP_XMAS_TREE_SCAN

# %%
finding_patter = df.groupby(['proto','service'])['Attack_type'].value_counts()
finding_patter
# Out:
# proto  service  Attack_type
# icmp   -        Thing_Speak                      45
#                 ARP_poisioning                    8
#                 NMAP_UDP_SCAN                     2
#                 Wipro_bulb                        2
# tcp    -        DOS_SYN_Hping                 94659
#                 NMAP_XMAS_TREE_SCAN            2006
#                 NMAP_OS_DETECTION              2000
#                 NMAP_TCP_scan                  1002
#                 ARP_poisioning                  214
#                 Wipro_bulb                       32
#                 NMAP_FIN_SCAN                    24
#                 Thing_Speak                      14
#                 MQTT_Publish                     11
#                 DDOS_Slowloris                    6
#                 NMAP_UDP_SCAN                     3
#        dns      ARP_poisioning                  125
#                 Thing_Speak                       1
# ...

# %%
df

# %%
attacks = df['Attack_type'].value_counts().nlargest(3)

# %%
checking = list(attacks.index)

# %%
checking
# Out:
# ['DOS_SYN_Hping', 'Thing_Speak', 'ARP_poisioning']

# %% [markdown]
# BASED ON THE OUTPUT WE CAN SEE THE PATTERN OF THE TOP 3 MOST COMMON ATTACK
# - ON THE TOP 1 WE CAN OBSERVE THAT DOS_SYN_HPING ATTACK always dont have a captured service
# - ON THE TOP 2 AND TOP 3 WHICH IS ARE THE Thing_Speak and ARP_poisoning does occur in any kind of services and protocols
#
# ADDITIONALLY
# - THEIR MOST COMMON SERVICE AND PROTOCOL IS DNS AND UDP

# %%
for name in checking:
    print(name)
    print(df[df['Attack_type'] == name][['service','proto']].value_counts())
# Out:
# DOS_SYN_Hping
# service  proto
# -        tcp      94659
# Name: count, dtype: int64
# Thing_Speak
# service  proto
# dns      udp      4068
# http     tcp      2667
# ssl      tcp      1097
# ntp      udp       110
# -        udp        92
#          icmp       45
#          tcp        14
# dhcp     udp        14
# dns      tcp         1
# Name: count, dtype: int64
# ARP_poisioning
# service  proto
# dns      udp      5458
# ssl      tcp      1459
# -        udp       324
#          tcp       214
# http     tcp       129
# dns      tcp       125
# dhcp     udp        26
# -        icmp        8
# ntp      udp         7
# Name: count, dtype: int64
