# %%
# !pip install sns
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sns in c:\users\user\appdata\roaming\python\python39\site-packages (0.1)

# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (3.5.2)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: numpy>=1.17 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# <font size = 7>EXTRACTION PHASE</font>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np


df = pd.read_csv("RT_IOT2022.csv")

df.head()
# Out:
#    no  id.orig_p  id.resp_p proto service  flow_duration  fwd_pkts_tot  \
# 0   0      38667       1883   tcp    mqtt      32.011598             9
# 1   1      51143       1883   tcp    mqtt      31.883584             9
# 2   2      44761       1883   tcp    mqtt      32.124053             9
# 3   3      60893       1883   tcp    mqtt      31.961063             9
# 4   4      51087       1883   tcp    mqtt      31.902362             9
#
#    bwd_pkts_tot  fwd_data_pkts_tot  bwd_data_pkts_tot  ...  active.std  \
# 0             5                  3                  3  ...         0.0
# 1             5                  3                  3  ...         0.0
# 2             5                  3                  3  ...         0.0
# 3             5                  3                  3  ...         0.0
# 4             5                  3                  3  ...         0.0
#
#        idle.min      idle.max      idle.tot      idle.avg  idle.std  \
# 0  2.972918e+07  2.972918e+07  2.972918e+07  2.972918e+07       0.0
# 1  2.985528e+07  2.985528e+07  2.985528e+07  2.985528e+07       0.0
# 2  2.984215e+07  2.984215e+07  2.984215e+07  2.984215e+07       0.0
# 3  2.991377e+07  2.991377e+07  2.991377e+07  2.991377e+07       0.0
# 4  2.981470e+07  2.981470e+07  2.981470e+07  2.981470e+07       0.0
#
#    fwd_init_window_size  bwd_init_window_size  fwd_last_window_size  \
# 0                 64240                 26847                   502
# 1                 64240                 26847                   502
# 2                 64240                 26847                   502
# 3                 64240                 26847                   502
# 4                 64240                 26847                   502
#
#     Attack_type
# 0  MQTT_Publish
# 1  MQTT_Publish
# 2  MQTT_Publish
# 3  MQTT_Publish
# 4  MQTT_Publish
#
# [5 rows x 85 columns]

# %% [markdown]
# <font size = 7>TRASNFORMATION PHASE</font>

# %%
#chech the datatype so the columns of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123117 entries, 0 to 123116
# Data columns (total 85 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   no                        123117 non-null  int64
#  1   id.orig_p                 123117 non-null  int64
#  2   id.resp_p                 123117 non-null  int64
#  3   proto                     123117 non-null  object
#  4   service                   123117 non-null  object
#  5   flow_duration             123117 non-null  float64
#  6   fwd_pkts_tot              123117 non-null  int64
#  7   bwd_pkts_tot              123117 non-null  int64
#  8   fwd_data_pkts_tot         123117 non-null  int64
#  9   bwd_data_pkts_tot         123117 non-null  int64
#  10  fwd_pkts_per_sec          123117 non-null  float64
#  11  bwd_pkts_per_sec          123117 non-null  float64
#  12  flow_pkts_per_sec         123117 non-null  float64
#  13  down_up_ratio             123117 non-null  float64
#  14  fwd_header_size_tot       123117 non-null  int64
#  15  fwd_header_size_min       123117 non-null  int64
#  16  fwd_header_size_max       123117 non-null  int64
#  17  bwd_header_size_tot       123117 non-null  int64
#  18  bwd_header_size_min       123117 non-null  int64
#  19  bwd_header_size_max       123117 non-null  int64
#  20  flow_FIN_flag_count       123117 non-null  int64
#  21  flow_SYN_flag_count       123117 non-null  int64
#  22  flow_RST_flag_count       123117 non-null  int64
#  23  fwd_PSH_flag_count        123117 non-null  int64
#  24  bwd_PSH_flag_count        123117 non-null  int64
#  25  flow_ACK_flag_count       123117 non-null  int64
#  26  fwd_URG_flag_count        123117 non-null  int64
#  27  bwd_URG_flag_count        123117 non-null  int64
#  28  flow_CWR_flag_count       123117 non-null  int64
#  29  flow_ECE_flag_count       123117 non-null  int64
#  30  fwd_pkts_payload.min      123117 non-null  float64
#  31  fwd_pkts_payload.max      123117 non-null  float64
#  32  fwd_pkts_payload.tot      123117 non-null  float64
#  33  fwd_pkts_payload.avg      123117 non-null  float64
#  34  fwd_pkts_payload.std      123117 non-null  float64
#  35  bwd_pkts_payload.min      123117 non-null  float64
#  36  bwd_pkts_payload.max      123117 non-null  float64
#  37  bwd_pkts_payload.tot      123117 non-null  float64
#  38  bwd_pkts_payload.avg      123117 non-null  float64
#  39  bwd_pkts_payload.std      123117 non-null  float64
#  40  flow_pkts_payload.min     123117 non-null  float64
#  41  flow_pkts_payload.max     123117 non-null  float64
#  42  flow_pkts_payload.tot     123117 non-null  float64
#  43  flow_pkts_payload.avg     123117 non-null  float64
#  44  flow_pkts_payload.std     123117 non-null  float64
#  45  fwd_iat.min               123117 non-null  float64
#  46  fwd_iat.max               123117 non-null  float64
#  47  fwd_iat.tot               123117 non-null  float64
#  48  fwd_iat.avg               123117 non-null  float64
#  49  fwd_iat.std               123117 non-null  float64
#  50  bwd_iat.min               123117 non-null  float64
#  51  bwd_iat.max               123117 non-null  float64
#  52  bwd_iat.tot               123117 non-null  float64
#  53  bwd_iat.avg               123117 non-null  float64
#  54  bwd_iat.std               123117 non-null  float64
#  55  flow_iat.min              123117 non-null  float64
#  56  flow_iat.max              123117 non-null  float64
#  57  flow_iat.tot              123117 non-null  float64
#  58  flow_iat.avg              123117 non-null  float64
#  59  flow_iat.std              123117 non-null  float64
#  60  payload_bytes_per_second  123117 non-null  float64
#  61  fwd_subflow_pkts          123117 non-null  float64
#  62  bwd_subflow_pkts          123117 non-null  float64
#  63  fwd_subflow_bytes         123117 non-null  float64
#  64  bwd_subflow_bytes         123117 non-null  float64
#  65  fwd_bulk_bytes            123117 non-null  float64
#  66  bwd_bulk_bytes            123117 non-null  float64
#  67  fwd_bulk_packets          123117 non-null  float64
#  68  bwd_bulk_packets          123117 non-null  float64
#  69  fwd_bulk_rate             123117 non-null  float64
#  70  bwd_bulk_rate             123117 non-null  float64
#  71  active.min                123117 non-null  float64
#  72  active.max                123117 non-null  float64
#  73  active.tot                123117 non-null  float64
#  74  active.avg                123117 non-null  float64
#  75  active.std                123117 non-null  float64
#  76  idle.min                  123117 non-null  float64
#  77  idle.max                  123117 non-null  float64
#  78  idle.tot                  123117 non-null  float64
#  79  idle.avg                  123117 non-null  float64
#  80  idle.std                  123117 non-null  float64
#  81  fwd_init_window_size      123117 non-null  int64
#  82  bwd_init_window_size      123117 non-null  int64
#  83  fwd_last_window_size      123117 non-null  int64
#  84  Attack_type               123117 non-null  object
# dtypes: float64(56), int64(26), object(3)
# memory usage: 79.8+ MB

# %%
# Check if there are columns that has null values
df.isnull().sum()
# Out:
# no                      0
# id.orig_p               0
# id.resp_p               0
# proto                   0
# service                 0
#                        ..
# idle.std                0
# fwd_init_window_size    0
# bwd_init_window_size    0
# fwd_last_window_size    0
# Attack_type             0
# Length: 85, dtype: int64

# %%
# Check columns of the dataframe to check if there are columns that have same name or duplicated
df.columns
# Out:
# Index(['no', 'id.orig_p', 'id.resp_p', 'proto', 'service', 'flow_duration',
#        'fwd_pkts_tot', 'bwd_pkts_tot', 'fwd_data_pkts_tot',
#        'bwd_data_pkts_tot', 'fwd_pkts_per_sec', 'bwd_pkts_per_sec',
#        'flow_pkts_per_sec', 'down_up_ratio', 'fwd_header_size_tot',
#        'fwd_header_size_min', 'fwd_header_size_max', 'bwd_header_size_tot',
#        'bwd_header_size_min', 'bwd_header_size_max', 'flow_FIN_flag_count',
#        'flow_SYN_flag_count', 'flow_RST_flag_count', 'fwd_PSH_flag_count',
#        'bwd_PSH_flag_count', 'flow_ACK_flag_count', 'fwd_URG_flag_count',
#        'bwd_URG_flag_count', 'flow_CWR_flag_count', 'flow_ECE_flag_count',
#        'fwd_pkts_payload.min', 'fwd_pkts_payload.max', 'fwd_pkts_payload.tot',
#        'fwd_pkts_payload.avg', 'fwd_pkts_payload.std', 'bwd_pkts_payload.min',
#        'bwd_pkts_payload.max', 'bwd_pkts_payload.tot', 'bwd_pkts_payload.avg',
#        'bwd_pkts_payload.std', 'flow_pkts_payload.min',
#        'flow_pkts_payload.max', 'flow_pkts_payload.tot',
#        'flow_pkts_payload.avg', 'flow_pkts_payload.std', 'fwd_iat.min',
#        'fwd_iat.max', 'fwd_iat.tot', 'fwd_iat.avg', 'fwd_iat.std',
#        'bwd_iat.min', 'bwd_iat.max', 'bwd_iat.tot', 'bwd_iat.avg',
#        'bwd_iat.std', 'flow_iat.min', 'flow_iat.max', 'flow_iat.tot',
#        'flow_iat.avg', 'flow_iat.std', 'payload_bytes_per_second',
#        'fwd_subflow_pkts', 'bwd_subflow_pkts', 'fwd_subflow_bytes',
#        'bwd_subflow_bytes', 'fwd_bulk_bytes', 'bwd_bulk_bytes',
#        'fwd_bulk_packets', 'bwd_bulk_packets', 'fwd_bulk_rate',
#        'bwd_bulk_rate', 'active.min', 'active.max', 'active.tot', 'active.avg',
#        'active.std', 'idle.min', 'idle.max', 'idle.tot', 'idle.avg',
#        'idle.std', 'fwd_init_window_size', 'bwd_init_window_size',
#        'fwd_last_window_size', 'Attack_type'],
#       dtype='object')

# %%
#check the shape of the dataframe
# to check the total rows and total columns of the dataset
df.shape
# Out:
# (123117, 85)

# %%
trial
# Out:
#           no  id.orig_p  id.resp_p proto service  flow_duration  fwd_pkts_tot  \
# 0          0      38667       1883   tcp    mqtt      32.011598             9
# 1          1      51143       1883   tcp    mqtt      31.883584             9
# 2          2      44761       1883   tcp    mqtt      32.124053             9
# 3          3      60893       1883   tcp    mqtt      31.961063             9
# 4          4      51087       1883   tcp    mqtt      31.902362             9
# ...      ...        ...        ...   ...     ...            ...           ...
# 123112  2005      59247      63331   tcp       -       0.000006             1
# 123113  2006      59247      64623   tcp       -       0.000007             1
# 123114  2007      59247      64680   tcp       -       0.000006             1
# 123115  2008      59247      65000   tcp       -       0.000006             1
# 123116  2009      59247      65129   tcp       -       0.000006             1
#
#         bwd_pkts_tot  fwd_data_pkts_tot  bwd_data_pkts_tot  ...  \
# 0                  5                  3                  3  ...
# 1                  5                  3                  3  ...
# 2                  5                  3                  3  ...
# 3                  5                  3                  3  ...
# 4                  5                  3                  3  ...
# ...              ...                ...                ...  ...
# 123112             1                  0                  0  ...
# 123113             1                  0                  0  ...
# 123114             1                  0                  0  ...
# 123115             1                  0                  0  ...
# 123116             1                  0                  0  ...
#
#         is_MQTT_Publish  is_Metasploit_Brute_Force_SSH  is_NMAP_FIN_SCAN  \
# 0                     1                              0                 0
# 1                     1                              0                 0
# 2                     1                              0                 0
# 3                     1                              0                 0
# 4                     1                              0                 0
# ...                 ...                            ...               ...
# 123112                0                              0                 0
# 123113                0                              0                 0
# 123114                0                              0                 0
# 123115                0                              0                 0
# 123116                0                              0                 0
#
#         is_NMAP_OS_DETECTION  is_NMAP_TCP_scan  is_NMAP_UDP_SCAN  \
# 0                          0                 0                 0
# 1                          0                 0                 0
# 2                          0                 0                 0
# 3                          0                 0                 0
# 4                          0                 0                 0
# ...                      ...               ...               ...
# 123112                     0                 0                 0
# 123113                     0                 0                 0
# 123114                     0                 0                 0
# 123115                     0                 0                 0
# 123116                     0                 0                 0
#
#         is_NMAP_XMAS_TREE_SCAN  is_Thing_Speak  is_Wipro_bulb  DISTINGUISH
# 0                            0               0              0       normal
# 1                            0               0              0       normal
# 2                            0               0              0       normal
# 3                            0               0              0       normal
# 4                            0               0              0       normal
# ...                        ...             ...            ...          ...
# 123112                       1               0              0       Attack
# 123113                       1               0              0       Attack
# 123114                       1               0              0       Attack
# 123115                       1               0              0       Attack
# 123116                       1               0              0       Attack
#
# [123117 rows x 98 columns]

# %%
trial['service'] = trial['service'].apply(lambda x: "No Service" if x == "-" else x)

# %%
trial
# Out:
#           no  id.orig_p  id.resp_p proto     service  flow_duration  \
# 0          0      38667       1883   tcp        mqtt      32.011598
# 1          1      51143       1883   tcp        mqtt      31.883584
# 2          2      44761       1883   tcp        mqtt      32.124053
# 3          3      60893       1883   tcp        mqtt      31.961063
# 4          4      51087       1883   tcp        mqtt      31.902362
# ...      ...        ...        ...   ...         ...            ...
# 123112  2005      59247      63331   tcp  No Service       0.000006
# 123113  2006      59247      64623   tcp  No Service       0.000007
# 123114  2007      59247      64680   tcp  No Service       0.000006
# 123115  2008      59247      65000   tcp  No Service       0.000006
# 123116  2009      59247      65129   tcp  No Service       0.000006
#
#         fwd_pkts_tot  bwd_pkts_tot  fwd_data_pkts_tot  bwd_data_pkts_tot  ...  \
# 0                  9             5                  3                  3  ...
# 1                  9             5                  3                  3  ...
# 2                  9             5                  3                  3  ...
# 3                  9             5                  3                  3  ...
# 4                  9             5                  3                  3  ...
# ...              ...           ...                ...                ...  ...
# 123112             1             1                  0                  0  ...
# 123113             1             1                  0                  0  ...
# 123114             1             1                  0                  0  ...
# 123115             1             1                  0                  0  ...
# 123116             1             1                  0                  0  ...
#
#         is_MQTT_Publish  is_Metasploit_Brute_Force_SSH  is_NMAP_FIN_SCAN  \
# 0                     1                              0                 0
# 1                     1                              0                 0
# 2                     1                              0                 0
# 3                     1                              0                 0
# 4                     1                              0                 0
# ...                 ...                            ...               ...
# 123112                0                              0                 0
# 123113                0                              0                 0
# 123114                0                              0                 0
# 123115                0                              0                 0
# 123116                0                              0                 0
#
#         is_NMAP_OS_DETECTION  is_NMAP_TCP_scan  is_NMAP_UDP_SCAN  \
# 0                          0                 0                 0
# 1                          0                 0                 0
# 2                          0                 0                 0
# 3                          0                 0                 0
# 4                          0                 0                 0
# ...                      ...               ...               ...
# 123112                     0                 0                 0
# 123113                     0                 0                 0
# 123114                     0                 0                 0
# 123115                     0                 0                 0
# 123116                     0                 0                 0
#
#         is_NMAP_XMAS_TREE_SCAN  is_Thing_Speak  is_Wipro_bulb  DISTINGUISH
# 0                            0               0              0       normal
# 1                            0               0              0       normal
# 2                            0               0              0       normal
# 3                            0               0              0       normal
# 4                            0               0              0       normal
# ...                        ...             ...            ...          ...
# 123112                       1               0              0       Attack
# 123113                       1               0              0       Attack
# 123114                       1               0              0       Attack
# 123115                       1               0              0       Attack
# 123116                       1               0              0       Attack
#
# [123117 rows x 98 columns]

# %% [markdown]
# <font size = 7>LOAD PHASE</font>

# %%
# create a copy of the dataset the to avoid overwritting the initial data of the dataframe and we can freely modify our dataset safely.
df_copy = df.copy()

# %% [markdown]
# <font size = 5>What is the distribution of the Attack_type classes (normal vs. various attacks), and what percentage of the 123,117 instances does each class comprise?</font>

# %%
df_copy.head()
# Out:
#    no  id.orig_p  id.resp_p proto service  flow_duration  fwd_pkts_tot  \
# 0   0      38667       1883   tcp    mqtt      32.011598             9
# 1   1      51143       1883   tcp    mqtt      31.883584             9
# 2   2      44761       1883   tcp    mqtt      32.124053             9
# 3   3      60893       1883   tcp    mqtt      31.961063             9
# 4   4      51087       1883   tcp    mqtt      31.902362             9
#
#    bwd_pkts_tot  fwd_data_pkts_tot  bwd_data_pkts_tot  ...  active.std  \
# 0             5                  3                  3  ...         0.0
# 1             5                  3                  3  ...         0.0
# 2             5                  3                  3  ...         0.0
# 3             5                  3                  3  ...         0.0
# 4             5                  3                  3  ...         0.0
#
#        idle.min      idle.max      idle.tot      idle.avg  idle.std  \
# 0  2.972918e+07  2.972918e+07  2.972918e+07  2.972918e+07       0.0
# 1  2.985528e+07  2.985528e+07  2.985528e+07  2.985528e+07       0.0
# 2  2.984215e+07  2.984215e+07  2.984215e+07  2.984215e+07       0.0
# 3  2.991377e+07  2.991377e+07  2.991377e+07  2.991377e+07       0.0
# 4  2.981470e+07  2.981470e+07  2.981470e+07  2.981470e+07       0.0
#
#    fwd_init_window_size  bwd_init_window_size  fwd_last_window_size  \
# 0                 64240                 26847                   502
# 1                 64240                 26847                   502
# 2                 64240                 26847                   502
# 3                 64240                 26847                   502
# 4                 64240                 26847                   502
#
#     Attack_type
# 0  MQTT_Publish
# 1  MQTT_Publish
# 2  MQTT_Publish
# 3  MQTT_Publish
# 4  MQTT_Publish
#
# [5 rows x 85 columns]

# %%
graph1 = df_copy['Attack_type'].value_counts(normalize = True)

# %%
graph1
# Out:
# DOS_SYN_Hping                 0.768854
# Thing_Speak                   0.065856
# ARP_poisioning                0.062948
# MQTT_Publish                  0.033675
# NMAP_UDP_SCAN                 0.021037
# NMAP_XMAS_TREE_SCAN           0.016326
# NMAP_OS_DETECTION             0.016245
# NMAP_TCP_scan                 0.008139
# DDOS_Slowloris                0.004337
# Wipro_bulb                    0.002055
# Metasploit_Brute_Force_SSH    0.000301
# NMAP_FIN_SCAN                 0.000227
# Name: Attack_type, dtype: float64

# %% [markdown]
# For the execution of the piechart
# - to keep the piechart organized, we sum up the lesser value or percentages of attack type in the distribution
# - to make this happen we set a treshhold of 1 percent

# %%
graph1 = df['Attack_type'].value_counts(normalize=True) * 100
threshold = 1
big = graph1[graph1 >= threshold]
small = graph1[graph1 < threshold]
big['Others'] = small.sum()

big.plot(kind='pie', figsize=(12, 8), labeldistance=1.1, autopct='%1.2f%%')
plt.title("Attack Type Distribution")
plt.show()

# %% [markdown]
# <font size = 5>How do the categorical features proto (protocol) and service vary across different attack types and normal traffic patterns? Links to an external site.</font>

# %%
# this shows the unique values of the column service
df_copy['service'].unique()
# Out:
# array(['mqtt', '-', 'http', 'dns', 'ntp', 'ssl', 'dhcp', 'irc', 'ssh',
#        'radius'], dtype=object)

# %%
# this shows the unique values of the column proto
df_copy['proto'].unique()
# Out:
# array(['tcp', 'udp', 'icmp'], dtype=object)

# %%
ser_proto = df_copy.groupby(['Attack_type'])[['service','proto']].value_counts()

# %%
ser_proto
# Out:
# Attack_type                 service  proto
# ARP_poisioning              dns      udp       5458
#                             ssl      tcp       1459
#                             -        udp        324
#                                      tcp        214
#                             http     tcp        129
#                             dns      tcp        125
#                             dhcp     udp         26
#                             -        icmp         8
#                             ntp      udp          7
# DDOS_Slowloris              http     tcp        523
#                             -        tcp          6
#                             dns      udp          3
#                             dhcp     udp          2
# DOS_SYN_Hping               -        tcp      94659
# MQTT_Publish                mqtt     tcp       4132
#                             -        tcp         11
#                             http     tcp          3
# Metasploit_Brute_Force_SSH  ssh      tcp         28
#                             dns      udp          8
#                             http     tcp          1
# NMAP_FIN_SCAN               -        tcp         24
#                             dns      udp          3
#                             http     tcp          1
# NMAP_OS_DETECTION           -        tcp       2000
# NMAP_TCP_scan               -        tcp       1002
# NMAP_UDP_SCAN               -        udp       2406
#                             http     tcp        139
#                             dns      udp         31
#                             ntp      udp          4
#                             -        tcp          3
#                             dhcp     udp          3
#                             radius   udp          2
#                             -        icmp         2
# NMAP_XMAS_TREE_SCAN         -        tcp       2006
#                             dns      udp          3
#                             http     tcp          1
# Thing_Speak                 dns      udp       4068
#                             http     tcp       2667
#                             ssl      tcp       1097
#                             ntp      udp        110
#                             -        udp         92
#                                      icmp        45
#                             dhcp     udp         14
#                             -        tcp         14
#                             dns      tcp          1
# Wipro_bulb                  ssl      tcp        107
#                             dns      udp         53
#                             irc      tcp         43
#                             -        tcp         32
#                                      udp         11
#                             dhcp     udp          5
#                             -        icmp         2
# dtype: int64

# %%
# get the service and protocol used of the top 3 most common attacks

# first we get top 3 attack types and insert it into a list for the loop 
top3 = list(graph1.nlargest(3).index)

# %%
collect_top3 = df_copy.query(f'Attack_type == {top3}')[['Attack_type','service','proto']]
collect_top3
# Out:
#           Attack_type service proto
# 4146      Thing_Speak    http   tcp
# 4147      Thing_Speak     dns   udp
# 4148      Thing_Speak    http   tcp
# 4149      Thing_Speak     dns   udp
# 4150      Thing_Speak    http   tcp
# ...               ...     ...   ...
# 115445  DOS_SYN_Hping       -   tcp
# 115446  DOS_SYN_Hping       -   tcp
# 115447  DOS_SYN_Hping       -   tcp
# 115448  DOS_SYN_Hping       -   tcp
# 115449  DOS_SYN_Hping       -   tcp
#
# [110517 rows x 3 columns]

# %%
collect_top3.set_index('Attack_type')
# Out:
#               service proto
# Attack_type
# Thing_Speak      http   tcp
# Thing_Speak       dns   udp
# Thing_Speak      http   tcp
# Thing_Speak       dns   udp
# Thing_Speak      http   tcp
# ...               ...   ...
# DOS_SYN_Hping       -   tcp
# DOS_SYN_Hping       -   tcp
# DOS_SYN_Hping       -   tcp
# DOS_SYN_Hping       -   tcp
# DOS_SYN_Hping       -   tcp
#
# [110517 rows x 2 columns]

# %%
graph4 = collect_top3.groupby(['Attack_type'])['proto'].value_counts()

#graph4.plot(kind = 'bar', y = graph4['proto'], x = graph4.index)
graph4
# Out:
# Attack_type     proto
# ARP_poisioning  udp       5815
#                 tcp       1927
#                 icmp         8
# DOS_SYN_Hping   tcp      94659
# Thing_Speak     udp       4284
#                 tcp       3779
#                 icmp        45
# Name: proto, dtype: int64

# %%
graph2 = collect_top3.groupby(['Attack_type'])['service'].value_counts()
graph2
# Out:
# Attack_type     service
# ARP_poisioning  dns         5583
#                 ssl         1459
#                 -            546
#                 http         129
#                 dhcp          26
#                 ntp            7
# DOS_SYN_Hping   -          94659
# Thing_Speak     dns         4069
#                 http        2667
#                 ssl         1097
#                 -            151
#                 ntp          110
#                 dhcp          14
# Name: service, dtype: int64

# %%
graph3 = collect_top3.groupby(['Attack_type'])['proto'].value_counts()
graph3
# Out:
# Attack_type     proto
# ARP_poisioning  udp       5815
#                 tcp       1927
#                 icmp         8
# DOS_SYN_Hping   tcp      94659
# Thing_Speak     udp       4284
#                 tcp       3779
#                 icmp        45
# Name: proto, dtype: int64

# %%
graph2.plot(kind = "bar", figsize = (12,8))
plt.title('')
plt.xlabel('')
plt.ylabel('')
plt.show()

# %%
graph3.plot(kind = "bar", figsize = (12,8))
plt.title('')
plt.xlabel('')
plt.ylabel('')
plt.show()

# %%
# base on count we observe that attack_Type DOS_SYN_Hping always dont have a captured service

df_copy[(df_copy['Attack_type'] == 'DOS_SYN_Hping') & (df_copy['service'] == '-')].describe()
# Out:
#                  no     id.orig_p  id.resp_p  flow_duration  fwd_pkts_tot  \
# count  94659.000000  94659.000000    94659.0   94659.000000       94659.0
# mean   47329.000000  30748.834892       21.0       0.000003           1.0
# std    27325.843903  19411.496837        0.0       0.000002           0.0
# min        0.000000      0.000000       21.0       0.000000           1.0
# 25%    23664.500000  12808.500000       21.0       0.000001           1.0
# 50%    47329.000000  30201.000000       21.0       0.000003           1.0
# 75%    70993.500000  47621.500000       21.0       0.000004           1.0
# max    94658.000000  65535.000000       21.0       0.000045           1.0
#
#        bwd_pkts_tot  fwd_data_pkts_tot  bwd_data_pkts_tot  fwd_pkts_per_sec  \
# count  94659.000000            94659.0            94659.0      9.465900e+04
# mean       0.897633                1.0                0.0      4.447962e+05
# std        0.303133                0.0                0.0      3.689500e+05
# min        0.000000                1.0                0.0      0.000000e+00
# 25%        1.000000                1.0                0.0      1.997288e+05
# 50%        1.000000                1.0                0.0      2.467238e+05
# 75%        1.000000                1.0                0.0      8.388608e+05
# max        1.000000                1.0                0.0      1.048576e+06
#
#        bwd_pkts_per_sec  ...    active.avg  active.std  idle.min  idle.max  \
# count      9.465900e+04  ...  94659.000000     94659.0   94659.0   94659.0
# mean       4.447962e+05  ...      2.727020         0.0       0.0       0.0
# std        3.689500e+05  ...      1.942489         0.0       0.0       0.0
# min        0.000000e+00  ...      0.000000         0.0       0.0       0.0
# 25%        1.997288e+05  ...      0.953674         0.0       0.0       0.0
# 50%        2.467238e+05  ...      3.099442         0.0       0.0       0.0
# 75%        8.388608e+05  ...      4.053116         0.0       0.0       0.0
# max        1.048576e+06  ...     45.061111         0.0       0.0       0.0
#
#        idle.tot  idle.avg  idle.std  fwd_init_window_size  \
# count   94659.0   94659.0   94659.0               94659.0
# mean        0.0       0.0       0.0                  64.0
# std         0.0       0.0       0.0                   0.0
# min         0.0       0.0       0.0                  64.0
# 25%         0.0       0.0       0.0                  64.0
# 50%         0.0       0.0       0.0                  64.0
# 75%         0.0       0.0       0.0                  64.0
# max         0.0       0.0       0.0                  64.0
#
#        bwd_init_window_size  fwd_last_window_size
# count               94659.0               94659.0
# mean                    0.0                  64.0
# std                     0.0                   0.0
# min                     0.0                  64.0
# 25%                     0.0                  64.0
# 50%                     0.0                  64.0
# 75%                     0.0                  64.0
# max                     0.0                  64.0
#
# [8 rows x 82 columns]

# %% [markdown]
# <font size= 5>What are the mean and standard deviation of flow_duration for each Attack_type, and are differences statistically significant?</font>

# %%
# by analyzing the statistical summary of flow_duration of every attack type
# we can determine if there are outliers in our data siply by comparing the mean,min,std, and max
# we this we can determine if the data is sparse or close
df_copy.groupby(['Attack_type'])['flow_duration'].describe()
# Out:
#                               count        mean          std       min  \
# Attack_type
# ARP_poisioning               7750.0   15.893538   108.261070  0.000000
# DDOS_Slowloris                534.0   14.699148    14.124797  0.000000
# DOS_SYN_Hping               94659.0    0.000003     0.000002  0.000000
# MQTT_Publish                 4146.0   43.397013    24.341563  0.000000
# Metasploit_Brute_Force_SSH     37.0    3.006557     5.210286  0.000000
# NMAP_FIN_SCAN                  28.0    0.023614     0.108791  0.000000
# NMAP_OS_DETECTION            2000.0    0.000008     0.000007  0.000001
# NMAP_TCP_scan                1002.0    0.000019     0.000269  0.000001
# NMAP_UDP_SCAN                2590.0    0.737766    24.909755  0.000000
# NMAP_XMAS_TREE_SCAN          2010.0    0.001171     0.050426  0.000000
# Thing_Speak                  8108.0    0.934471     5.251602  0.000000
# Wipro_bulb                    253.0  586.845727  2738.891637  0.000000
#
#                                   25%        50%        75%           max
# Attack_type
# ARP_poisioning               0.000000   0.000637   0.307533   5341.392332
# DDOS_Slowloris               0.003817  20.088963  30.557698     30.870463
# DOS_SYN_Hping                0.000001   0.000003   0.000004      0.000045
# MQTT_Publish                30.022991  44.067645  61.973033    353.112391
# Metasploit_Brute_Force_SSH   1.417588   2.030317   2.258765     29.289262
# NMAP_FIN_SCAN                0.000000   0.000000   0.000000      0.575884
# NMAP_OS_DETECTION            0.000005   0.000006   0.000007      0.000048
# NMAP_TCP_scan                0.000002   0.000004   0.000005      0.005989
# NMAP_UDP_SCAN                0.000000   0.000000   0.000000    905.964201
# NMAP_XMAS_TREE_SCAN          0.000006   0.000007   0.000008      2.260214
# Thing_Speak                  0.029932   0.114787   0.878177    184.414081
# Wipro_bulb                   0.027666   0.803326  31.285402  21728.335578

# %%
# for the visualization lets check it using the violin graph

fig, axes = plt.subplots(figsize=(10, 5))
sns.violinplot(
x='Attack_type', y='flow_duration', data=df_copy[['Attack_type', 'flow_duration']],
ax=axes, scale='width')
plt.xticks(rotation = 90)
plt.suptitle('Comparing Attack_type by flow_duration')
# Out:
# Text(0.5, 0.98, 'Comparing Attack_type by flow_duration')

# %% [markdown]
# <font size = 5>Which continuous features (e.g., fwd_pkts_per_sec, bwd_pkts_per_sec, payload_bytes_per_second) exhibit the highest correlation with specific attack classes?</font>

# %%
# creating another copy for trial and error
correlation = df_copy.copy()

# %%
# For the most common attack which is the DOS_SYN_Hping attack we observe that the following 
# variable have positive correlation to the most common attack type


correlation['is_DOS_SYN_Hping'] = (correlation['Attack_type'] == 'DOS_SYN_Hping').astype(int)
cor = correlation[['fwd_pkts_per_sec', 'bwd_pkts_per_sec', 'payload_bytes_per_second', 'is_DOS_SYN_Hping']].corr()
test = cor.tail(1)

# %%
row = cor.loc['is_DOS_SYN_Hping'].drop('is_DOS_SYN_Hping')


plt.figure(figsize=(8, 5))
row.plot(kind='bar', color='teal')
plt.title("Correlation of Features with DOS_SYN_Hping")
plt.ylabel("Correlation Coefficient")
plt.xlabel("Feature")
plt.ylim(-1, 1)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(rotation= 45)
plt.tight_layout()
plt.show()

# %% [markdown]
# <font size =5>How do time‑based features like fwd_iat.avg and bwd_iat.avg (mean inter‑arrival times) differ between various attack types and normal traffic?</font>

# %%
time_avg = df_copy[['fwd_iat.avg','bwd_iat.avg','Attack_type']]

# %%
time_avg
# Out:
#          fwd_iat.avg    bwd_iat.avg          Attack_type
# 0       4.001450e+06  506597.757339         MQTT_Publish
# 1       3.985448e+06  469065.248966         MQTT_Publish
# 2       4.015507e+06  503442.466259         MQTT_Publish
# 3       3.995133e+06  470946.013927         MQTT_Publish
# 4       3.987795e+06  483996.033669         MQTT_Publish
# ...              ...            ...                  ...
# 123112  0.000000e+00       0.000000  NMAP_XMAS_TREE_SCAN
# 123113  0.000000e+00       0.000000  NMAP_XMAS_TREE_SCAN
# 123114  0.000000e+00       0.000000  NMAP_XMAS_TREE_SCAN
# 123115  0.000000e+00       0.000000  NMAP_XMAS_TREE_SCAN
# 123116  0.000000e+00       0.000000  NMAP_XMAS_TREE_SCAN
#
# [123117 rows x 3 columns]

# %%
time_avg.groupby(['Attack_type'])[['fwd_iat.avg','bwd_iat.avg']].describe()
# Out:
#                            fwd_iat.avg                                   \
#                                  count          mean           std  min
# Attack_type
# ARP_poisioning                  7750.0  7.443455e+05  6.080604e+06  0.0
# DDOS_Slowloris                   534.0  2.660823e+06  2.505477e+06  0.0
# DOS_SYN_Hping                  94659.0  0.000000e+00  0.000000e+00  0.0
# MQTT_Publish                    4146.0  4.941675e+06  2.703778e+06  0.0
# Metasploit_Brute_Force_SSH        37.0  4.313227e+05  1.071899e+06  0.0
# NMAP_FIN_SCAN                     28.0  4.114728e+03  2.176702e+04  0.0
# NMAP_OS_DETECTION               2000.0  0.000000e+00  0.000000e+00  0.0
# NMAP_TCP_scan                   1002.0  7.311979e+00  1.345700e+02  0.0
# NMAP_UDP_SCAN                   2590.0  1.436467e+04  4.294105e+05  0.0
# NMAP_XMAS_TREE_SCAN             2010.0  1.874295e+02  8.402341e+03  0.0
# Thing_Speak                     8108.0  1.186232e+05  8.328482e+05  0.0
# Wipro_bulb                       253.0  2.093047e+06  7.004656e+06  0.0
#
#                                                                       \
#                                      25%           50%           75%
# Attack_type
# ARP_poisioning              0.000000e+00  8.106232e+00  3.036066e+04
# DDOS_Slowloris              1.263877e+03  4.362737e+06  5.107711e+06
# DOS_SYN_Hping               0.000000e+00  0.000000e+00  0.000000e+00
# MQTT_Publish                3.439565e+06  5.009167e+06  6.886319e+06
# Metasploit_Brute_Force_SSH  1.096741e+05  1.480301e+05  1.706666e+05
# NMAP_FIN_SCAN               0.000000e+00  0.000000e+00  0.000000e+00
# NMAP_OS_DETECTION           0.000000e+00  0.000000e+00  0.000000e+00
# NMAP_TCP_scan               0.000000e+00  0.000000e+00  0.000000e+00
# NMAP_UDP_SCAN               0.000000e+00  0.000000e+00  0.000000e+00
# NMAP_XMAS_TREE_SCAN         0.000000e+00  0.000000e+00  0.000000e+00
# Thing_Speak                 2.729893e+02  4.441249e+04  1.242706e+05
# Wipro_bulb                  0.000000e+00  9.106379e+04  1.859183e+06
#
#                                          bwd_iat.avg                \
#                                      max       count          mean
# Attack_type
# ARP_poisioning              3.002526e+08      7750.0  7.664256e+05
# DDOS_Slowloris              6.103740e+06       534.0  2.523958e+06
# DOS_SYN_Hping               0.000000e+00     94659.0  0.000000e+00
# MQTT_Publish                3.923471e+07      4146.0  5.222072e+05
# Metasploit_Brute_Force_SSH  4.313726e+06        37.0  9.100383e+05
# NMAP_FIN_SCAN               1.151814e+05        28.0  6.539123e+03
# NMAP_OS_DETECTION           0.000000e+00      2000.0  0.000000e+00
# NMAP_TCP_scan               2.994537e+03      1002.0  0.000000e+00
# NMAP_UDP_SCAN               2.067726e+07      2590.0  1.786866e+02
# NMAP_XMAS_TREE_SCAN         3.767023e+05      2010.0  1.716461e+02
# Thing_Speak                 4.351004e+07      8108.0  9.726068e+04
# Wipro_bulb                  9.104470e+07       253.0  2.037756e+06
#
#                                                                             \
#                                      std  min            25%           50%
# Attack_type
# ARP_poisioning              3.813601e+06  0.0       0.000000  1.041889e+02
# DDOS_Slowloris              2.760618e+06  0.0    1784.354448  2.563950e+06
# DOS_SYN_Hping               0.000000e+00  0.0       0.000000  0.000000e+00
# MQTT_Publish                1.378185e+06  0.0  383927.249909  3.996923e+05
# Metasploit_Brute_Force_SSH  4.747146e+06  0.0  106390.496095  1.665667e+05
# NMAP_FIN_SCAN               2.776590e+04  0.0       0.000000  0.000000e+00
# NMAP_OS_DETECTION           0.000000e+00  0.0       0.000000  0.000000e+00
# NMAP_TCP_scan               0.000000e+00  0.0       0.000000  0.000000e+00
# NMAP_UDP_SCAN               4.287451e+03  0.0       0.000000  0.000000e+00
# NMAP_XMAS_TREE_SCAN         6.956765e+03  0.0       0.000000  0.000000e+00
# Thing_Speak                 5.627067e+05  0.0   19559.711215  5.721104e+04
# Wipro_bulb                  6.598996e+06  0.0       0.000000  6.206238e+04
#
#
#                                      75%           max
# Attack_type
# ARP_poisioning              6.787091e+04  1.501489e+08
# DDOS_Slowloris              5.092944e+06  1.058325e+07
# DOS_SYN_Hping               0.000000e+00  0.000000e+00
# MQTT_Publish                4.476724e+05  3.044517e+07
# Metasploit_Brute_Force_SSH  1.847412e+05  2.900158e+07
# NMAP_FIN_SCAN               0.000000e+00  1.427865e+05
# NMAP_OS_DETECTION           0.000000e+00  0.000000e+00
# NMAP_TCP_scan               0.000000e+00  0.000000e+00
# NMAP_UDP_SCAN               0.000000e+00  1.434383e+05
# NMAP_XMAS_TREE_SCAN         0.000000e+00  3.099315e+05
# Thing_Speak                 1.249998e+05  4.319622e+07
# Wipro_bulb                  1.855113e+06  4.967098e+07

# %%
indexer = time_avg.groupby(['Attack_type'])[['fwd_iat.avg','bwd_iat.avg']].describe()
picked_attacks = list(indexer.index)
traffic_check = df_copy.query(f'Attack_type == {picked_attacks} ')
graph1 = traffic_check.groupby(['Attack_type'])[['fwd_iat.avg','bwd_iat.avg']].mean()

# %%
graph1
# Out:
#                              fwd_iat.avg   bwd_iat.avg
# Attack_type
# ARP_poisioning              7.443455e+05  7.664256e+05
# DDOS_Slowloris              2.660823e+06  2.523958e+06
# DOS_SYN_Hping               0.000000e+00  0.000000e+00
# MQTT_Publish                4.941675e+06  5.222072e+05
# Metasploit_Brute_Force_SSH  4.313227e+05  9.100383e+05
# NMAP_FIN_SCAN               4.114728e+03  6.539123e+03
# NMAP_OS_DETECTION           0.000000e+00  0.000000e+00
# NMAP_TCP_scan               7.311979e+00  0.000000e+00
# NMAP_UDP_SCAN               1.436467e+04  1.786866e+02
# NMAP_XMAS_TREE_SCAN         1.874295e+02  1.716461e+02
# Thing_Speak                 1.186232e+05  9.726068e+04
# Wipro_bulb                  2.093047e+06  2.037756e+06

# %%
graph1.plot(kind = 'bar', figsize = (12,8))
plt.show()

# %% [markdown]
# <font size =5>Which network flag counts (e.g., flow_SYN_flag_count, flow_RST_flag_count, fwd_PSH_flag_count) are most indicative of specific intrusion patterns?</font>

# %%
flag_features = [col for col in df_copy.columns if '_flag_count' in col]

# %%
flag_features
# Out:
# ['flow_FIN_flag_count',
#  'flow_SYN_flag_count',
#  'flow_RST_flag_count',
#  'fwd_PSH_flag_count',
#  'bwd_PSH_flag_count',
#  'flow_ACK_flag_count',
#  'fwd_URG_flag_count',
#  'bwd_URG_flag_count',
#  'flow_CWR_flag_count',
#  'flow_ECE_flag_count']

# %%
correlation_matrix = pd.DataFrame()

for attack in picked_attacks:
    df[f'is_{attack}'] = (df['Attack_type'] == attack).astype(int)
    temp_cor = df[flag_features + [f'is_{attack}']].corr().loc[flag_features, f'is_{attack}']
    correlation_matrix[attack] = temp_cor

# Plot it
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title("Correlation of Flag Counts with Attack Types")
plt.tight_layout()
plt.show()

# %% [markdown]
# <font size =5 ></font>

# %% [markdown]
# <font size= 5>CREATING SPERATE CSV FOR NORMAL TRAFFIC AND ATTACKS</font>

# %%
df['Attack_type'].unique()
# Out:
# array(['MQTT_Publish', 'Thing_Speak', 'Wipro_bulb', 'ARP_poisioning',
#        'DDOS_Slowloris', 'DOS_SYN_Hping', 'Metasploit_Brute_Force_SSH',
#        'NMAP_FIN_SCAN', 'NMAP_OS_DETECTION', 'NMAP_TCP_scan',
#        'NMAP_UDP_SCAN', 'NMAP_XMAS_TREE_SCAN'], dtype=object)

# %%
normal_trfc = ['MQTT_Publish','Thing_Speak','Wipro_bulb']

# %%
lists = list(df['Attack_type'].unique())
lists
# Out:
# ['MQTT_Publish',
#  'Thing_Speak',
#  'Wipro_bulb',
#  'ARP_poisioning',
#  'DDOS_Slowloris',
#  'DOS_SYN_Hping',
#  'Metasploit_Brute_Force_SSH',
#  'NMAP_FIN_SCAN',
#  'NMAP_OS_DETECTION',
#  'NMAP_TCP_scan',
#  'NMAP_UDP_SCAN',
#  'NMAP_XMAS_TREE_SCAN']

# %%
attaks_list = [x for x in lists if x not in normal_trfc]
attaks_list
# Out:
# ['ARP_poisioning',
#  'DDOS_Slowloris',
#  'DOS_SYN_Hping',
#  'Metasploit_Brute_Force_SSH',
#  'NMAP_FIN_SCAN',
#  'NMAP_OS_DETECTION',
#  'NMAP_TCP_scan',
#  'NMAP_UDP_SCAN',
#  'NMAP_XMAS_TREE_SCAN']

# %%
df_attack = df.query(f'Attack_type == {attaks_list}')

# %%
df_attack.head()
# Out:
#        no  id.orig_p  id.resp_p proto service  flow_duration  fwd_pkts_tot  \
# 12507   0       5353       5353   udp     dns       0.000000             1
# 12508   1       5353       5353   udp     dns       0.000000             1
# 12509   2      53544        443   tcp       -      42.492044             9
# 12510   3      53542        443   tcp       -      42.515244             9
# 12511   4      60654        443   tcp       -      43.726695             8
#
#        bwd_pkts_tot  fwd_data_pkts_tot  bwd_data_pkts_tot  ...  \
# 12507             0                  1                  0  ...
# 12508             0                  1                  0  ...
# 12509             7                  1                  1  ...
# 12510             7                  1                  1  ...
# 12511             7                  1                  0  ...
#
#        is_DOS_SYN_Hping  is_MQTT_Publish  is_Metasploit_Brute_Force_SSH  \
# 12507                 0                0                              0
# 12508                 0                0                              0
# 12509                 0                0                              0
# 12510                 0                0                              0
# 12511                 0                0                              0
#
#        is_NMAP_FIN_SCAN  is_NMAP_OS_DETECTION  is_NMAP_TCP_scan  \
# 12507                 0                     0                 0
# 12508                 0                     0                 0
# 12509                 0                     0                 0
# 12510                 0                     0                 0
# 12511                 0                     0                 0
#
#        is_NMAP_UDP_SCAN  is_NMAP_XMAS_TREE_SCAN  is_Thing_Speak  is_Wipro_bulb
# 12507                 0                       0               0              0
# 12508                 0                       0               0              0
# 12509                 0                       0               0              0
# 12510                 0                       0               0              0
# 12511                 0                       0               0              0
#
# [5 rows x 97 columns]

# %%
df_normal = df.query(f'Attack_type == {normal_trfc}')

# %%
df_normal.head()
# Out:
#    no  id.orig_p  id.resp_p proto service  flow_duration  fwd_pkts_tot  \
# 0   0      38667       1883   tcp    mqtt      32.011598             9
# 1   1      51143       1883   tcp    mqtt      31.883584             9
# 2   2      44761       1883   tcp    mqtt      32.124053             9
# 3   3      60893       1883   tcp    mqtt      31.961063             9
# 4   4      51087       1883   tcp    mqtt      31.902362             9
#
#    bwd_pkts_tot  fwd_data_pkts_tot  bwd_data_pkts_tot  ...  is_DOS_SYN_Hping  \
# 0             5                  3                  3  ...                 0
# 1             5                  3                  3  ...                 0
# 2             5                  3                  3  ...                 0
# 3             5                  3                  3  ...                 0
# 4             5                  3                  3  ...                 0
#
#    is_MQTT_Publish  is_Metasploit_Brute_Force_SSH  is_NMAP_FIN_SCAN  \
# 0                1                              0                 0
# 1                1                              0                 0
# 2                1                              0                 0
# 3                1                              0                 0
# 4                1                              0                 0
#
#    is_NMAP_OS_DETECTION  is_NMAP_TCP_scan  is_NMAP_UDP_SCAN  \
# 0                     0                 0                 0
# 1                     0                 0                 0
# 2                     0                 0                 0
# 3                     0                 0                 0
# 4                     0                 0                 0
#
#    is_NMAP_XMAS_TREE_SCAN  is_Thing_Speak  is_Wipro_bulb
# 0                       0               0              0
# 1                       0               0              0
# 2                       0               0              0
# 3                       0               0              0
# 4                       0               0              0
#
# [5 rows x 97 columns]

# %% [markdown]
# <font size = 5>CREATING DISTRIBUTION FOR NORMAL AND ATTACKS</font>

# %%
attack_dist = df_attack['Attack_type'].value_counts(normalize = True)*100

# %%
attack_dist
# Out:
# DOS_SYN_Hping                 85.579062
# ARP_poisioning                 7.006600
# NMAP_UDP_SCAN                  2.341560
# NMAP_XMAS_TREE_SCAN            1.817196
# NMAP_OS_DETECTION              1.808155
# NMAP_TCP_scan                  0.905886
# DDOS_Slowloris                 0.482777
# Metasploit_Brute_Force_SSH     0.033451
# NMAP_FIN_SCAN                  0.025314
# Name: Attack_type, dtype: float64

# %%
normal_dist = df_normal['Attack_type'].value_counts(normalize = True)*100

# %%
normal_dist
# Out:
# Thing_Speak     64.827696
# MQTT_Publish    33.149436
# Wipro_bulb       2.022867
# Name: Attack_type, dtype: float64

# %%
attack_dist.plot(kind = 'pie')
plt.show()

# %%
graph1 = df['Attack_type'].value_counts(normalize=True) * 100
threshold = 1
big = graph1[graph1 >= threshold]
small = graph1[graph1 < threshold]
big['Others'] = small.sum()

# %%
labels = ['vegetable', 'fruit']
sizes = [300, 200]
labels_vegefruit = ['potato', 'tomato', 'onion', 'apple',
                    'banana', 'cherry', 'durian']
sizes_vegefruit = [170, 70, 60, 70, 60, 50, 20]
colors = ['#FFB600', '#09A0DA']
colors_vegefruit = ['#FFCE53', '#FFDA7E', '#FFE9B2', '#30B7EA',
                    '#56C7F2','#7FD6F7', '#B3E7FB']
 
bigger = plt.pie(sizes, labels=labels, colors=colors,
                 startangle=90, frame=True)
smaller = plt.pie(sizes_vegefruit, labels=labels_vegefruit,
                  colors=colors_vegefruit, radius=0.7,
                  startangle=90, labeldistance=0.7)
centre_circle = plt.Circle((0, 0), 0.4, color='white', linewidth=0)
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
        
plt.axis('equal')
plt.tight_layout()

plt.show()

# %%
trial = df.copy()

# %%
trial['DISTINGUISH'] = ['Attack' if x in attaks_list else 'normal' for x in trial['Attack_type']]

# %%
trial['DISTINGUISH']
# Out:
# 0         normal
# 1         normal
# 2         normal
# 3         normal
# 4         normal
#            ...
# 123112    Attack
# 123113    Attack
# 123114    Attack
# 123115    Attack
# 123116    Attack
# Name: DISTINGUISH, Length: 123117, dtype: object

# %%
overall_distribution = trial.groupby(['DISTINGUISH'])['Attack_type'].value_counts()

# %%
main_counter = trial['DISTINGUISH'].value_counts()

# %%
main_counter
# Out:
# Attack    110610
# normal     12507
# Name: DISTINGUISH, dtype: int64

# %%
bigger = main_counter.plot(kind = 'pie', startangle= 90,autopct='%1.2f%%')
plt.title('Distribution of normal traffics and attacks in the dataset')
plt.show()

# %%
graph5 = df_normal['Attack_type'].value_counts()

# %%
graphs5 = graph5.plot(kind= "bar", figsize = (12,8),color = "royalblue")
for container in graphs5.containers:
    for bar in container:
        height = bar.get_height()
        graphs5.text(bar.get_x() + bar.get_width() / 2, height + 50, f'{height:.0f}', 
                ha='center', va='bottom', fontsize=7)

plt.title('Distribution of the nornal traffics in the dataset')
plt.xlabel('type of traffics')
plt.ylabel('total counts')
plt.grid(color = "#95a5a6", linestyle = "--",linewidth = 2, axis = 'y',alpha = 0.7)
plt.xticks(rotation = 45)
plt.show()

# %%
graph6 = df_attack['Attack_type'].value_counts()

# %%
graphs6 = graph6.plot(kind = 'bar', figsize = (12,8), color = 'royalblue')
for container in graphs6.containers:
    for bar in container:
        height = bar.get_height()
        graphs6.text(bar.get_x() + bar.get_width() / 2, height + 50, f'{height:.0f}', 
                ha='center', va='bottom', fontsize=7)


plt.title('Distribution of Attack in the dataset')
plt.xlabel('Attack type')
plt.ylabel('total couts')
plt.xticks(rotation = 45)
plt.grid(color = "#95a5a6", linestyle = "--",linewidth = 2, axis = 'y',alpha = 0.7)
plt.show()

# %%
overall_distribution
# Out:
# DISTINGUISH  Attack_type
# Attack       DOS_SYN_Hping                 94659
#              ARP_poisioning                 7750
#              NMAP_UDP_SCAN                  2590
#              NMAP_XMAS_TREE_SCAN            2010
#              NMAP_OS_DETECTION              2000
#              NMAP_TCP_scan                  1002
#              DDOS_Slowloris                  534
#              Metasploit_Brute_Force_SSH       37
#              NMAP_FIN_SCAN                    28
# normal       Thing_Speak                    8108
#              MQTT_Publish                   4146
#              Wipro_bulb                      253
# Name: Attack_type, dtype: int64

# %%
# Out:
# Attack    110610
# normal     12507
# Name: DISTINGUISH, dtype: int64

# %%
overall = trial['Attack_type'].value_counts()

# %%
overall
# Out:
# DOS_SYN_Hping                 94659
# Thing_Speak                    8108
# ARP_poisioning                 7750
# MQTT_Publish                   4146
# NMAP_UDP_SCAN                  2590
# NMAP_XMAS_TREE_SCAN            2010
# NMAP_OS_DETECTION              2000
# NMAP_TCP_scan                  1002
# DDOS_Slowloris                  534
# Wipro_bulb                      253
# Metasploit_Brute_Force_SSH       37
# NMAP_FIN_SCAN                    28
# Name: Attack_type, dtype: int64

# %%
graph7 = trial.groupby(['service', 'DISTINGUISH']).size().unstack(fill_value=0)
graphs7 = graph7.plot(kind='bar', figsize=(12, 6), width  = 1)
for container in graphs7.containers:
    for bar in container:
        height = bar.get_height()
        graphs7.text(bar.get_x() + bar.get_width() / 2, height + 50, f'{height:.0f}', 
                ha='center', va='bottom', fontsize=7)
plt.title('total count of service used by attacker and normal traffics')
plt.xlabel('kinds of service')
plt.ylabel('total counts')
plt.xticks(rotation = 45)
plt.show()

# %%
graph7
# Out:
# service  DISTINGUISH
# -        Attack         102654
#          normal            207
# dhcp     Attack             31
#          normal             19
# dns      Attack           5631
#          normal           4122
# http     normal           2670
#          Attack            794
# irc      normal             43
# mqtt     normal           4132
# ntp      normal            110
#          Attack             11
# radius   Attack              2
# ssh      Attack             28
# ssl      Attack           1459
#          normal           1204
# Name: DISTINGUISH, dtype: int64

# %%
graph8 = trial.groupby(['proto', 'DISTINGUISH']).size().unstack(fill_value=0)
graph8.plot(kind='bar', figsize=(12, 6))
plt.title('total count of protocol used by attacker and normal traffics')
plt.xlabel('kinds of protocols')
plt.ylabel('total counts')
plt.xticks(rotation = 45)
plt.show()
